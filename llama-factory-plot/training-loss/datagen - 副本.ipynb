# %%
import json
import matplotlib.pyplot as plt

# Define file paths
multiturn_file_path = './trainer_log_k20.jsonl'
singleturn_file_path = './trainer_log_k20.jsonl'

# Function to read data from a JSONL file
def read_jsonl(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    return [json.loads(line) for line in lines]

# Read data from files
multiturn_data = read_jsonl(multiturn_file_path)
singleturn_data = read_jsonl(singleturn_file_path)

# %%
multiturn_data
# Out:
# [{'current_steps': 1,
#   'total_steps': 9729,
#   'eval_loss': 1.761314868927002,
#   'epoch': 0.00030827328426650223,
#   'percentage': 0.01,
#   'elapsed_time': '0:00:16',
#   'remaining_time': '1 day, 19:54:57'},
#  {'current_steps': 2,
#   'total_steps': 9729,
#   'eval_loss': 1.7522867918014526,
#   'epoch': 0.0006165465685330045,
#   'percentage': 0.02,
#   'elapsed_time': '0:00:31',
#   'remaining_time': '1 day, 18:38:19'},
#  {'current_steps': 3,
#   'total_steps': 9729,
#   'eval_loss': 1.7463115453720093,
#   'epoch': 0.0009248198527995068,
#   'percentage': 0.03,
#   'elapsed_time': '0:00:46',
#   'remaining_time': '1 day, 18:01:37'},
#  {'current_steps': 4,
#   'total_steps': 9729,
#   'eval_loss': 1.7298718690872192,
#   'epoch': 0.001233093137066009,
#   'percentage': 0.04,
#   'elapsed_time': '0:01:02',
#   'remaining_time': '1 day, 18:04:14'},
#  {'current_steps': 5,
#   'total_steps': 9729,
#   'eval_loss': 1.7170242071151733,
#   'epoch': 0.0015413664213325114,
#   'percentage': 0.05,
#   'elapsed_time': '0:01:17',
#   'remaining_time': '1 day, 17:56:25'},
#  {'current_steps': 6,
#   'total_steps': 9729,
#   'eval_loss': 1.7121303081512451,
#   'epoch': 0.0018496397055990136,
#   'percentage': 0.06,
#   'elapsed_time': '0:01:33',
#   'remaining_time': '1 day, 17:56:15'},
#  {'current_steps': 7,
#   'total_steps': 9729,
#   'eval_loss': 1.7089660167694092,
#   'epoch': 0.0021579129898655156,
#   'percentage': 0.07,
#   'elapsed_time': '0:01:48',
#   'remaining_time': '1 day, 17:58:40'},
#  {'current_steps': 8,
#   'total_steps': 9729,
#   'eval_loss': 1.6901342868804932,
#   'epoch': 0.002466186274132018,
#   'percentage': 0.08,
#   'elapsed_time': '0:02:04',
#   'remaining_time': '1 day, 18:04:50'},
#  {'current_steps': 9,
#   'total_steps': 9729,
#   'eval_loss': 1.6654947996139526,
#   'epoch': 0.00277445955839852,
#   'percentage': 0.09,
#   'elapsed_time': '0:02:19',
#   'remaining_time': '1 day, 17:58:00'},
#  {'current_steps': 10,
#   'total_steps': 9729,
#   'loss': 1.9849,
#   'learning_rate': 9.999973932284655e-07,
#   'epoch': 0.0030827328426650227,
#   'percentage': 0.1,
#   'elapsed_time': '0:02:25',
#   'remaining_time': '1 day, 15:09:42'},
#  {'current_steps': 10,
#   'total_steps': 9729,
#   'eval_loss': 1.6585898399353027,
#   'epoch': 0.0030827328426650227,
#   'percentage': 0.1,
#   'elapsed_time': '0:02:35',
#   'remaining_time': '1 day, 17:59:00'},
#  {'current_steps': 11,
#   'total_steps': 9729,
#   'eval_loss': 1.6536685228347778,
#   'epoch': 0.003391006126931525,
#   'percentage': 0.11,
#   'elapsed_time': '0:02:51',
#   'remaining_time': '1 day, 17:59:05'},
#  {'current_steps': 12,
#   'total_steps': 9729,
#   'eval_loss': 1.6482592821121216,
#   'epoch': 0.003699279411198027,
#   'percentage': 0.12,
#   'elapsed_time': '0:03:07',
#   'remaining_time': '1 day, 18:12:32'},
#  {'current_steps': 13,
#   'total_steps': 9729,
#   'eval_loss': 1.6428226232528687,
#   'epoch': 0.004007552695464529,
#   'percentage': 0.13,
#   'elapsed_time': '0:03:23',
#   'remaining_time': '1 day, 18:10:42'},
#  {'current_steps': 14,
#   'total_steps': 9729,
#   'eval_loss': 1.6369802951812744,
#   'epoch': 0.004315825979731031,
#   'percentage': 0.14,
#   'elapsed_time': '0:03:39',
#   'remaining_time': '1 day, 18:22:23'},
#  {'current_steps': 15,
#   'total_steps': 9729,
#   'eval_loss': 1.631892442703247,
#   'epoch': 0.0046240992639975335,
#   'percentage': 0.15,
#   'elapsed_time': '0:03:55',
#   'remaining_time': '1 day, 18:21:26'},
#  {'current_steps': 16,
#   'total_steps': 9729,
#   'eval_loss': 1.6226165294647217,
#   'epoch': 0.004932372548264036,
#   'percentage': 0.16,
#   'elapsed_time': '0:04:10',
#   'remaining_time': '1 day, 18:18:12'},
#  {'current_steps': 17,
#   'total_steps': 9729,
#   'eval_loss': 1.6105568408966064,
#   'epoch': 0.005240645832530538,
#   'percentage': 0.17,
#   'elapsed_time': '0:04:27',
#   'remaining_time': '1 day, 18:22:23'},
#  {'current_steps': 18,
#   'total_steps': 9729,
#   'eval_loss': 1.5970678329467773,
#   'epoch': 0.00554891911679704,
#   'percentage': 0.19,
#   'elapsed_time': '0:04:42',
#   'remaining_time': '1 day, 18:19:42'},
#  {'current_steps': 19,
#   'total_steps': 9729,
#   'eval_loss': 1.5861315727233887,
#   'epoch': 0.005857192401063542,
#   'percentage': 0.2,
#   'elapsed_time': '0:04:59',
#   'remaining_time': '1 day, 18:28:47'},
#  {'current_steps': 20,
#   'total_steps': 9729,
#   'loss': 1.6105,
#   'learning_rate': 9.999895729410435e-07,
#   'epoch': 0.0061654656853300455,
#   'percentage': 0.21,
#   'elapsed_time': '0:05:04',
#   'remaining_time': '1 day, 17:03:36'},
#  {'current_steps': 20,
#   'total_steps': 9729,
#   'eval_loss': 1.5735136270523071,
#   'epoch': 0.0061654656853300455,
#   'percentage': 0.21,
#   'elapsed_time': '0:05:14',
#   'remaining_time': '1 day, 18:28:10'},
#  {'current_steps': 21,
#   'total_steps': 9729,
#   'eval_loss': 1.5659962892532349,
#   'epoch': 0.006473738969596548,
#   'percentage': 0.22,
#   'elapsed_time': '0:05:30',
#   'remaining_time': '1 day, 18:29:59'},
#  {'current_steps': 22,
#   'total_steps': 9729,
#   'eval_loss': 1.5560139417648315,
#   'epoch': 0.00678201225386305,
#   'percentage': 0.23,
#   'elapsed_time': '0:05:47',
#   'remaining_time': '1 day, 18:35:50'},
#  {'current_steps': 23,
#   'total_steps': 9729,
#   'eval_loss': 1.5478339195251465,
#   'epoch': 0.007090285538129552,
#   'percentage': 0.24,
#   'elapsed_time': '0:06:03',
#   'remaining_time': '1 day, 18:37:58'},
#  {'current_steps': 24,
#   'total_steps': 9729,
#   'eval_loss': 1.5393195152282715,
#   'epoch': 0.007398558822396054,
#   'percentage': 0.25,
#   'elapsed_time': '0:06:20',
#   'remaining_time': '1 day, 18:41:41'},
#  {'current_steps': 25,
#   'total_steps': 9729,
#   'eval_loss': 1.5308692455291748,
#   'epoch': 0.007706832106662557,
#   'percentage': 0.26,
#   'elapsed_time': '0:06:35',
#   'remaining_time': '1 day, 18:36:16'},
#  {'current_steps': 26,
#   'total_steps': 9729,
#   'eval_loss': 1.5236871242523193,
#   'epoch': 0.008015105390929058,
#   'percentage': 0.27,
#   'elapsed_time': '0:06:51',
#   'remaining_time': '1 day, 18:39:40'},
#  {'current_steps': 27,
#   'total_steps': 9729,
#   'eval_loss': 1.515870213508606,
#   'epoch': 0.00832337867519556,
#   'percentage': 0.28,
#   'elapsed_time': '0:07:07',
#   'remaining_time': '1 day, 18:38:50'},
#  {'current_steps': 28,
#   'total_steps': 9729,
#   'eval_loss': 1.5085439682006836,
#   'epoch': 0.008631651959462062,
#   'percentage': 0.29,
#   'elapsed_time': '0:07:23',
#   'remaining_time': '1 day, 18:39:16'},
#  {'current_steps': 29,
#   'total_steps': 9729,
#   'eval_loss': 1.50008225440979,
#   'epoch': 0.008939925243728565,
#   'percentage': 0.3,
#   'elapsed_time': '0:07:38',
#   'remaining_time': '1 day, 18:37:32'},
#  {'current_steps': 30,
#   'total_steps': 9729,
#   'loss': 1.6181,
#   'learning_rate': 9.999765392192766e-07,
#   'epoch': 0.009248198527995067,
#   'percentage': 0.31,
#   'elapsed_time': '0:07:44',
#   'remaining_time': '1 day, 17:45:04'},
#  {'current_steps': 30,
#   'total_steps': 9729,
#   'eval_loss': 1.4924813508987427,
#   'epoch': 0.009248198527995067,
#   'percentage': 0.31,
#   'elapsed_time': '0:07:55',
#   'remaining_time': '1 day, 18:41:26'},
#  {'current_steps': 31,
#   'total_steps': 9729,
#   'eval_loss': 1.4839988946914673,
#   'epoch': 0.00955647181226157,
#   'percentage': 0.32,
#   'elapsed_time': '0:08:12',
#   'remaining_time': '1 day, 18:47:02'},
#  {'current_steps': 32,
#   'total_steps': 9729,
#   'eval_loss': 1.4744774103164673,
#   'epoch': 0.009864745096528071,
#   'percentage': 0.33,
#   'elapsed_time': '0:08:28',
#   'remaining_time': '1 day, 18:49:42'},
#  {'current_steps': 33,
#   'total_steps': 9729,
#   'eval_loss': 1.4649351835250854,
#   'epoch': 0.010173018380794574,
#   'percentage': 0.34,
#   'elapsed_time': '0:08:44',
#   'remaining_time': '1 day, 18:47:21'},
#  {'current_steps': 34,
#   'total_steps': 9729,
#   'eval_loss': 1.4585384130477905,
#   'epoch': 0.010481291665061076,
#   'percentage': 0.35,
#   'elapsed_time': '0:09:00',
#   'remaining_time': '1 day, 18:48:36'},
#  {'current_steps': 35,
#   'total_steps': 9729,
#   'eval_loss': 1.4513754844665527,
#   'epoch': 0.010789564949327578,
#   'percentage': 0.36,
#   'elapsed_time': '0:09:16',
#   'remaining_time': '1 day, 18:46:40'},
#  {'current_steps': 36,
#   'total_steps': 9729,
#   'eval_loss': 1.4458295106887817,
#   'epoch': 0.01109783823359408,
#   'percentage': 0.37,
#   'elapsed_time': '0:09:31',
#   'remaining_time': '1 day, 18:45:34'},
#  {'current_steps': 37,
#   'total_steps': 9729,
#   'eval_loss': 1.4396727085113525,
#   'epoch': 0.011406111517860583,
#   'percentage': 0.38,
#   'elapsed_time': '0:09:47',
#   'remaining_time': '1 day, 18:42:54'},
#  {'current_steps': 38,
#   'total_steps': 9729,
#   'eval_loss': 1.4364246129989624,
#   'epoch': 0.011714384802127085,
#   'percentage': 0.39,
#   'elapsed_time': '0:10:03',
#   'remaining_time': '1 day, 18:43:32'},
#  {'current_steps': 39,
#   'total_steps': 9729,
#   'eval_loss': 1.431108832359314,
#   'epoch': 0.012022658086393589,
#   'percentage': 0.4,
#   'elapsed_time': '0:10:19',
#   'remaining_time': '1 day, 18:44:35'},
#  {'current_steps': 40,
#   'total_steps': 9729,
#   'loss': 1.48,
#   'learning_rate': 9.999582921990683e-07,
#   'epoch': 0.012330931370660091,
#   'percentage': 0.41,
#   'elapsed_time': '0:10:24',
#   'remaining_time': '1 day, 18:00:19'},
#  {'current_steps': 40,
#   'total_steps': 9729,
#   'eval_loss': 1.429100513458252,
#   'epoch': 0.012330931370660091,
#   'percentage': 0.41,
#   'elapsed_time': '0:10:34',
#   'remaining_time': '1 day, 18:42:33'},
#  {'current_steps': 41,
#   'total_steps': 9729,
#   'eval_loss': 1.4237555265426636,
#   'epoch': 0.012639204654926593,
#   'percentage': 0.42,
#   'elapsed_time': '0:10:50',
#   'remaining_time': '1 day, 18:40:25'},
#  {'current_steps': 42,
#   'total_steps': 9729,
#   'eval_loss': 1.420332431793213,
#   'epoch': 0.012947477939193095,
#   'percentage': 0.43,
#   'elapsed_time': '0:11:05',
#   'remaining_time': '1 day, 18:39:28'},
#  {'current_steps': 43,
#   'total_steps': 9729,
#   'eval_loss': 1.4156063795089722,
#   'epoch': 0.013255751223459598,
#   'percentage': 0.44,
#   'elapsed_time': '0:11:21',
#   'remaining_time': '1 day, 18:38:21'},
#  {'current_steps': 44,
#   'total_steps': 9729,
#   'eval_loss': 1.412474513053894,
#   'epoch': 0.0135640245077261,
#   'percentage': 0.45,
#   'elapsed_time': '0:11:37',
#   'remaining_time': '1 day, 18:37:53'},
#  {'current_steps': 45,
#   'total_steps': 9729,
#   'eval_loss': 1.4093444347381592,
#   'epoch': 0.013872297791992602,
#   'percentage': 0.46,
#   'elapsed_time': '0:11:52',
#   'remaining_time': '1 day, 18:36:37'},
#  {'current_steps': 46,
#   'total_steps': 9729,
#   'eval_loss': 1.4062832593917847,
#   'epoch': 0.014180571076259104,
#   'percentage': 0.47,
#   'elapsed_time': '0:12:09',
#   'remaining_time': '1 day, 18:37:53'},
#  {'current_steps': 47,
#   'total_steps': 9729,
#   'eval_loss': 1.4056761264801025,
#   'epoch': 0.014488844360525607,
#   'percentage': 0.48,
#   'elapsed_time': '0:12:24',
#   'remaining_time': '1 day, 18:37:46'},
#  {'current_steps': 48,
#   'total_steps': 9729,
#   'eval_loss': 1.403527021408081,
#   'epoch': 0.014797117644792109,
#   'percentage': 0.49,
#   'elapsed_time': '0:12:40',
#   'remaining_time': '1 day, 18:37:46'},
#  {'current_steps': 49,
#   'total_steps': 9729,
#   'eval_loss': 1.4003422260284424,
#   'epoch': 0.015105390929058611,
#   'percentage': 0.5,
#   'elapsed_time': '0:12:57',
#   'remaining_time': '1 day, 18:39:29'},
#  {'current_steps': 50,
#   'total_steps': 9729,
#   'loss': 1.5595,
#   'learning_rate': 9.999348320706825e-07,
#   'epoch': 0.015413664213325113,
#   'percentage': 0.51,
#   'elapsed_time': '0:13:02',
#   'remaining_time': '1 day, 18:03:48'},
#  {'current_steps': 50,
#   'total_steps': 9729,
#   'eval_loss': 1.3973183631896973,
#   'epoch': 0.015413664213325113,
#   'percentage': 0.51,
#   'elapsed_time': '0:13:12',
#   'remaining_time': '1 day, 18:37:32'},
#  {'current_steps': 51,
#   'total_steps': 9729,
#   'eval_loss': 1.394004464149475,
#   'epoch': 0.015721937497591616,
#   'percentage': 0.52,
#   'elapsed_time': '0:13:27',
#   'remaining_time': '1 day, 18:35:28'},
#  {'current_steps': 52,
#   'total_steps': 9729,
#   'eval_loss': 1.3914742469787598,
#   'epoch': 0.016030210781858116,
#   'percentage': 0.53,
#   'elapsed_time': '0:13:43',
#   'remaining_time': '1 day, 18:34:03'},
#  {'current_steps': 53,
#   'total_steps': 9729,
#   'eval_loss': 1.3892886638641357,
#   'epoch': 0.01633848406612462,
#   'percentage': 0.54,
#   'elapsed_time': '0:13:58',
#   'remaining_time': '1 day, 18:32:14'},
#  {'current_steps': 54,
#   'total_steps': 9729,
#   'eval_loss': 1.386656641960144,
#   'epoch': 0.01664675735039112,
#   'percentage': 0.56,
#   'elapsed_time': '0:14:14',
#   'remaining_time': '1 day, 18:32:53'},
#  {'current_steps': 55,
#   'total_steps': 9729,
#   'eval_loss': 1.3829073905944824,
#   'epoch': 0.016955030634657624,
#   'percentage': 0.57,
#   'elapsed_time': '0:14:30',
#   'remaining_time': '1 day, 18:32:31'},
#  {'current_steps': 56,
#   'total_steps': 9729,
#   'eval_loss': 1.3802534341812134,
#   'epoch': 0.017263303918924125,
#   'percentage': 0.58,
#   'elapsed_time': '0:14:46',
#   'remaining_time': '1 day, 18:33:04'},
#  {'current_steps': 57,
#   'total_steps': 9729,
#   'eval_loss': 1.3771709203720093,
#   'epoch': 0.01757157720319063,
#   'percentage': 0.59,
#   'elapsed_time': '0:15:02',
#   'remaining_time': '1 day, 18:32:23'},
#  {'current_steps': 58,
#   'total_steps': 9729,
#   'eval_loss': 1.3725547790527344,
#   'epoch': 0.01787985048745713,
#   'percentage': 0.6,
#   'elapsed_time': '0:15:18',
#   'remaining_time': '1 day, 18:31:27'},
#  {'current_steps': 59,
#   'total_steps': 9729,
#   'eval_loss': 1.3685922622680664,
#   'epoch': 0.018188123771723633,
#   'percentage': 0.61,
#   'elapsed_time': '0:15:34',
#   'remaining_time': '1 day, 18:32:18'},
#  {'current_steps': 60,
#   'total_steps': 9729,
#   'loss': 1.437,
#   'learning_rate': 9.999061590787393e-07,
#   'epoch': 0.018496397055990134,
#   'percentage': 0.62,
#   'elapsed_time': '0:15:39',
#   'remaining_time': '1 day, 18:04:22'},
#  {'current_steps': 60,
#   'total_steps': 9729,
#   'eval_loss': 1.3660796880722046,
#   'epoch': 0.018496397055990134,
#   'percentage': 0.62,
#   'elapsed_time': '0:15:50',
#   'remaining_time': '1 day, 18:32:28'},
#  {'current_steps': 61,
#   'total_steps': 9729,
#   'eval_loss': 1.3614689111709595,
#   'epoch': 0.018804670340256638,
#   'percentage': 0.63,
#   'elapsed_time': '0:16:06',
#   'remaining_time': '1 day, 18:32:40'},
#  {'current_steps': 62,
#   'total_steps': 9729,
#   'eval_loss': 1.359784722328186,
#   'epoch': 0.01911294362452314,
#   'percentage': 0.64,
#   'elapsed_time': '0:16:21',
#   'remaining_time': '1 day, 18:31:09'},
#  {'current_steps': 63,
#   'total_steps': 9729,
#   'eval_loss': 1.3585028648376465,
#   'epoch': 0.019421216908789642,
#   'percentage': 0.65,
#   'elapsed_time': '0:16:37',
#   'remaining_time': '1 day, 18:31:47'},
#  {'current_steps': 64,
#   'total_steps': 9729,
#   'eval_loss': 1.3569514751434326,
#   'epoch': 0.019729490193056143,
#   'percentage': 0.66,
#   'elapsed_time': '0:16:54',
#   'remaining_time': '1 day, 18:32:43'},
#  {'current_steps': 65,
#   'total_steps': 9729,
#   'eval_loss': 1.3547139167785645,
#   'epoch': 0.020037763477322647,
#   'percentage': 0.67,
#   'elapsed_time': '0:17:10',
#   'remaining_time': '1 day, 18:33:18'},
#  {'current_steps': 66,
#   'total_steps': 9729,
#   'eval_loss': 1.3525211811065674,
#   'epoch': 0.020346036761589147,
#   'percentage': 0.68,
#   'elapsed_time': '0:17:26',
#   'remaining_time': '1 day, 18:34:08'},
#  {'current_steps': 67,
#   'total_steps': 9729,
#   'eval_loss': 1.3501161336898804,
#   'epoch': 0.02065431004585565,
#   'percentage': 0.69,
#   'elapsed_time': '0:17:43',
#   'remaining_time': '1 day, 18:36:45'},
#  {'current_steps': 68,
#   'total_steps': 9729,
#   'eval_loss': 1.3479090929031372,
#   'epoch': 0.020962583330122152,
#   'percentage': 0.7,
#   'elapsed_time': '0:18:00',
#   'remaining_time': '1 day, 18:37:21'},
#  {'current_steps': 69,
#   'total_steps': 9729,
#   'eval_loss': 1.3469277620315552,
#   'epoch': 0.021270856614388656,
#   'percentage': 0.71,
#   'elapsed_time': '0:18:16',
#   'remaining_time': '1 day, 18:38:26'},
#  {'current_steps': 70,
#   'total_steps': 9729,
#   'loss': 1.3105,
#   'learning_rate': 9.998722735222147e-07,
#   'epoch': 0.021579129898655156,
#   'percentage': 0.72,
#   'elapsed_time': '0:18:22',
#   'remaining_time': '1 day, 18:15:26'},
#  {'current_steps': 70,
#   'total_steps': 9729,
#   'eval_loss': 1.344622015953064,
#   'epoch': 0.021579129898655156,
#   'percentage': 0.72,
#   'elapsed_time': '0:18:32',
#   'remaining_time': '1 day, 18:39:29'},
#  {'current_steps': 71,
#   'total_steps': 9729,
#   'eval_loss': 1.3426024913787842,
#   'epoch': 0.02188740318292166,
#   'percentage': 0.73,
#   'elapsed_time': '0:18:48',
#   'remaining_time': '1 day, 18:39:12'},
#  {'current_steps': 72,
#   'total_steps': 9729,
#   'eval_loss': 1.3438400030136108,
#   'epoch': 0.02219567646718816,
#   'percentage': 0.74,
#   'elapsed_time': '0:19:04',
#   'remaining_time': '1 day, 18:39:11'},
#  {'current_steps': 73,
#   'total_steps': 9729,
#   'eval_loss': 1.3432461023330688,
#   'epoch': 0.022503949751454665,
#   'percentage': 0.75,
#   'elapsed_time': '0:19:21',
#   'remaining_time': '1 day, 18:40:06'},
#  {'current_steps': 74,
#   'total_steps': 9729,
#   'eval_loss': 1.3421883583068848,
#   'epoch': 0.022812223035721165,
#   'percentage': 0.76,
#   'elapsed_time': '0:19:37',
#   'remaining_time': '1 day, 18:40:18'},
#  {'current_steps': 75,
#   'total_steps': 9729,
#   'eval_loss': 1.3416012525558472,
#   'epoch': 0.02312049631998767,
#   'percentage': 0.77,
#   'elapsed_time': '0:19:52',
#   'remaining_time': '1 day, 18:38:27'},
#  {'current_steps': 76,
#   'total_steps': 9729,
#   'eval_loss': 1.3416301012039185,
#   'epoch': 0.02342876960425417,
#   'percentage': 0.78,
#   'elapsed_time': '0:20:08',
#   'remaining_time': '1 day, 18:38:40'},
#  {'current_steps': 77,
#   'total_steps': 9729,
#   'eval_loss': 1.3405942916870117,
#   'epoch': 0.023737042888520674,
#   'percentage': 0.79,
#   'elapsed_time': '0:20:24',
#   'remaining_time': '1 day, 18:38:13'},
#  {'current_steps': 78,
#   'total_steps': 9729,
#   'eval_loss': 1.339747428894043,
#   'epoch': 0.024045316172787178,
#   'percentage': 0.8,
#   'elapsed_time': '0:20:41',
#   'remaining_time': '1 day, 18:39:20'},
#  {'current_steps': 79,
#   'total_steps': 9729,
#   'eval_loss': 1.3401379585266113,
#   'epoch': 0.024353589457053678,
#   'percentage': 0.81,
#   'elapsed_time': '0:20:57',
#   'remaining_time': '1 day, 18:39:12'},
#  {'current_steps': 80,
#   'total_steps': 9729,
#   'loss': 1.4199,
#   'learning_rate': 9.998331757544365e-07,
#   'epoch': 0.024661862741320182,
#   'percentage': 0.82,
#   'elapsed_time': '0:21:02',
#   'remaining_time': '1 day, 18:18:05'},
#  {'current_steps': 80,
#   'total_steps': 9729,
#   'eval_loss': 1.3349692821502686,
#   'epoch': 0.024661862741320182,
#   'percentage': 0.82,
#   'elapsed_time': '0:21:13',
#   'remaining_time': '1 day, 18:39:06'},
#  {'current_steps': 81,
#   'total_steps': 9729,
#   'eval_loss': 1.33469557762146,
#   'epoch': 0.024970136025586682,
#   'percentage': 0.83,
#   'elapsed_time': '0:21:28',
#   'remaining_time': '1 day, 18:38:48'},
#  {'current_steps': 82,
#   'total_steps': 9729,
#   'eval_loss': 1.3327269554138184,
#   'epoch': 0.025278409309853186,
#   'percentage': 0.84,
#   'elapsed_time': '0:21:45',
#   'remaining_time': '1 day, 18:38:52'},
#  {'current_steps': 83,
#   'total_steps': 9729,
#   'eval_loss': 1.3295292854309082,
#   'epoch': 0.025586682594119687,
#   'percentage': 0.85,
#   'elapsed_time': '0:22:00',
#   'remaining_time': '1 day, 18:37:37'},
#  {'current_steps': 84,
#   'total_steps': 9729,
#   'eval_loss': 1.3292224407196045,
#   'epoch': 0.02589495587838619,
#   'percentage': 0.86,
#   'elapsed_time': '0:22:17',
#   'remaining_time': '1 day, 18:38:37'},
#  {'current_steps': 85,
#   'total_steps': 9729,
#   'eval_loss': 1.3288019895553589,
#   'epoch': 0.02620322916265269,
#   'percentage': 0.87,
#   'elapsed_time': '0:22:33',
#   'remaining_time': '1 day, 18:39:45'},
#  {'current_steps': 86,
#   'total_steps': 9729,
#   'eval_loss': 1.3269981145858765,
#   'epoch': 0.026511502446919195,
#   'percentage': 0.88,
#   'elapsed_time': '0:22:49',
#   'remaining_time': '1 day, 18:39:45'},
#  {'current_steps': 87,
#   'total_steps': 9729,
#   'eval_loss': 1.3254650831222534,
#   'epoch': 0.026819775731185696,
#   'percentage': 0.89,
#   'elapsed_time': '0:23:05',
#   'remaining_time': '1 day, 18:38:42'},
#  {'current_steps': 88,
#   'total_steps': 9729,
#   'eval_loss': 1.3258306980133057,
#   'epoch': 0.0271280490154522,
#   'percentage': 0.9,
#   'elapsed_time': '0:23:20',
#   'remaining_time': '1 day, 18:37:29'},
#  {'current_steps': 89,
#   'total_steps': 9729,
#   'eval_loss': 1.3263287544250488,
#   'epoch': 0.0274363222997187,
#   'percentage': 0.91,
#   'elapsed_time': '0:23:36',
#   'remaining_time': '1 day, 18:36:37'},
#  {'current_steps': 90,
#   'total_steps': 9729,
#   'loss': 1.315,
#   'learning_rate': 9.997888661830802e-07,
#   'epoch': 0.027744595583985204,
#   'percentage': 0.93,
#   'elapsed_time': '0:23:42',
#   'remaining_time': '1 day, 18:18:16'},
#  {'current_steps': 90,
#   'total_steps': 9729,
#   'eval_loss': 1.3263845443725586,
#   'epoch': 0.027744595583985204,
#   'percentage': 0.93,
#   'elapsed_time': '0:23:52',
#   'remaining_time': '1 day, 18:36:56'},
#  {'current_steps': 91,
#   'total_steps': 9729,
#   'eval_loss': 1.3249810934066772,
#   'epoch': 0.028052868868251705,
#   'percentage': 0.94,
#   'elapsed_time': '0:24:08',
#   'remaining_time': '1 day, 18:36:37'},
#  {'current_steps': 92,
#   'total_steps': 9729,
#   'eval_loss': 1.3247020244598389,
#   'epoch': 0.02836114215251821,
#   'percentage': 0.95,
#   'elapsed_time': '0:24:23',
#   'remaining_time': '1 day, 18:34:57'},
#  {'current_steps': 93,
#   'total_steps': 9729,
#   'eval_loss': 1.3232558965682983,
#   'epoch': 0.02866941543678471,
#   'percentage': 0.96,
#   'elapsed_time': '0:24:40',
#   'remaining_time': '1 day, 18:36:42'},
#  {'current_steps': 94,
#   'total_steps': 9729,
#   'eval_loss': 1.3229457139968872,
#   'epoch': 0.028977688721051213,
#   'percentage': 0.97,
#   'elapsed_time': '0:24:57',
#   'remaining_time': '1 day, 18:37:38'},
#  {'current_steps': 95,
#   'total_steps': 9729,
#   'eval_loss': 1.321928858757019,
#   'epoch': 0.029285962005317714,
#   'percentage': 0.98,
#   'elapsed_time': '0:25:13',
#   'remaining_time': '1 day, 18:37:21'},
#  {'current_steps': 96,
#   'total_steps': 9729,
#   'eval_loss': 1.3204494714736938,
#   'epoch': 0.029594235289584218,
#   'percentage': 0.99,
#   'elapsed_time': '0:25:29',
#   'remaining_time': '1 day, 18:38:38'},
#  {'current_steps': 97,
#   'total_steps': 9729,
#   'eval_loss': 1.3213257789611816,
#   'epoch': 0.029902508573850718,
#   'percentage': 1.0,
#   'elapsed_time': '0:25:45',
#   'remaining_time': '1 day, 18:37:44'},
#  {'current_steps': 98,
#   'total_steps': 9729,
#   'eval_loss': 1.323549747467041,
#   'epoch': 0.030210781858117222,
#   'percentage': 1.01,
#   'elapsed_time': '0:26:00',
#   'remaining_time': '1 day, 18:36:38'},
#  {'current_steps': 99,
#   'total_steps': 9729,
#   'eval_loss': 1.326544165611267,
#   'epoch': 0.030519055142383723,
#   'percentage': 1.02,
#   'elapsed_time': '0:26:18',
#   'remaining_time': '1 day, 18:38:55'},
#  {'current_steps': 100,
#   'total_steps': 9729,
#   'loss': 1.2995,
#   'learning_rate': 9.997393452701659e-07,
#   'epoch': 0.030827328426650227,
#   'percentage': 1.03,
#   'elapsed_time': '0:26:23',
#   'remaining_time': '1 day, 18:20:57'},
#  {'current_steps': 100,
#   'total_steps': 9729,
#   'eval_loss': 1.328263521194458,
#   'epoch': 0.030827328426650227,
#   'percentage': 1.03,
#   'elapsed_time': '0:26:33',
#   'remaining_time': '1 day, 18:37:44'},
#  {'current_steps': 101,
#   'total_steps': 9729,
#   'eval_loss': 1.3246492147445679,
#   'epoch': 0.031135601710916727,
#   'percentage': 1.04,
#   'elapsed_time': '0:26:49',
#   'remaining_time': '1 day, 18:37:51'},
#  {'current_steps': 102,
#   'total_steps': 9729,
#   'eval_loss': 1.3209006786346436,
#   'epoch': 0.03144387499518323,
#   'percentage': 1.05,
#   'elapsed_time': '0:27:05',
#   'remaining_time': '1 day, 18:37:01'},
#  {'current_steps': 103,
#   'total_steps': 9729,
#   'eval_loss': 1.3173317909240723,
#   'epoch': 0.031752148279449735,
#   'percentage': 1.06,
#   'elapsed_time': '0:27:21',
#   'remaining_time': '1 day, 18:36:24'},
#  {'current_steps': 104,
#   'total_steps': 9729,
#   'eval_loss': 1.3193913698196411,
#   'epoch': 0.03206042156371623,
#   'percentage': 1.07,
#   'elapsed_time': '0:27:37',
#   'remaining_time': '1 day, 18:36:01'},
#  {'current_steps': 105,
#   'total_steps': 9729,
#   'eval_loss': 1.321709394454956,
#   'epoch': 0.032368694847982736,
#   'percentage': 1.08,
#   'elapsed_time': '0:27:53',
#   'remaining_time': '1 day, 18:36:09'},
#  {'current_steps': 106,
#   'total_steps': 9729,
#   'eval_loss': 1.3226306438446045,
#   'epoch': 0.03267696813224924,
#   'percentage': 1.09,
#   'elapsed_time': '0:28:09',
#   'remaining_time': '1 day, 18:36:17'},
#  {'current_steps': 107,
#   'total_steps': 9729,
#   'eval_loss': 1.323274850845337,
#   'epoch': 0.032985241416515744,
#   'percentage': 1.1,
#   'elapsed_time': '0:28:24',
#   'remaining_time': '1 day, 18:35:20'},
#  {'current_steps': 108,
#   'total_steps': 9729,
#   'eval_loss': 1.325107216835022,
#   'epoch': 0.03329351470078224,
#   'percentage': 1.11,
#   'elapsed_time': '0:28:41',
#   'remaining_time': '1 day, 18:35:23'},
#  {'current_steps': 109,
#   'total_steps': 9729,
#   'eval_loss': 1.326338291168213,
#   'epoch': 0.033601787985048745,
#   'percentage': 1.12,
#   'elapsed_time': '0:28:57',
#   'remaining_time': '1 day, 18:36:10'},
#  {'current_steps': 110,
#   'total_steps': 9729,
#   'loss': 1.4632,
#   'learning_rate': 9.99684613532052e-07,
#   'epoch': 0.03391006126931525,
#   'percentage': 1.13,
#   'elapsed_time': '0:29:03',
#   'remaining_time': '1 day, 18:21:06'},
#  {'current_steps': 110,
#   'total_steps': 9729,
#   'eval_loss': 1.3262988328933716,
#   'epoch': 0.03391006126931525,
#   'percentage': 1.13,
#   'elapsed_time': '0:29:14',
#   'remaining_time': '1 day, 18:36:20'},
#  {'current_steps': 111,
#   'total_steps': 9729,
#   'eval_loss': 1.3259724378585815,
#   'epoch': 0.03421833455358175,
#   'percentage': 1.14,
#   'elapsed_time': '0:29:29',
#   'remaining_time': '1 day, 18:35:21'},
#  {'current_steps': 112,
#   'total_steps': 9729,
#   'eval_loss': 1.324405550956726,
#   'epoch': 0.03452660783784825,
#   'percentage': 1.15,
#   'elapsed_time': '0:29:45',
#   'remaining_time': '1 day, 18:35:06'},
#  {'current_steps': 113,
#   'total_steps': 9729,
#   'eval_loss': 1.3229894638061523,
#   'epoch': 0.034834881122114754,
#   'percentage': 1.16,
#   'elapsed_time': '0:30:01',
#   'remaining_time': '1 day, 18:35:14'},
#  {'current_steps': 114,
#   'total_steps': 9729,
#   'eval_loss': 1.321923851966858,
#   'epoch': 0.03514315440638126,
#   'percentage': 1.17,
#   'elapsed_time': '0:30:18',
#   'remaining_time': '1 day, 18:35:38'},
#  {'current_steps': 115,
#   'total_steps': 9729,
#   'eval_loss': 1.3217337131500244,
#   'epoch': 0.03545142769064776,
#   'percentage': 1.18,
#   'elapsed_time': '0:30:34',
#   'remaining_time': '1 day, 18:35:31'},
#  {'current_steps': 116,
#   'total_steps': 9729,
#   'eval_loss': 1.3209911584854126,
#   'epoch': 0.03575970097491426,
#   'percentage': 1.19,
#   'elapsed_time': '0:30:49',
#   'remaining_time': '1 day, 18:34:52'},
#  {'current_steps': 117,
#   'total_steps': 9729,
#   'eval_loss': 1.3184990882873535,
#   'epoch': 0.03606797425918076,
#   'percentage': 1.2,
#   'elapsed_time': '0:31:06',
#   'remaining_time': '1 day, 18:35:00'},
#  {'current_steps': 118,
#   'total_steps': 9729,
#   'eval_loss': 1.319393277168274,
#   'epoch': 0.03637624754344727,
#   'percentage': 1.21,
#   'elapsed_time': '0:31:21',
#   'remaining_time': '1 day, 18:33:52'},
#  {'current_steps': 119,
#   'total_steps': 9729,
#   'eval_loss': 1.320556640625,
#   'epoch': 0.03668452082771377,
#   'percentage': 1.22,
#   'elapsed_time': '0:31:37',
#   'remaining_time': '1 day, 18:33:51'},
#  {'current_steps': 120,
#   'total_steps': 9729,
#   'loss': 1.4227,
#   'learning_rate': 9.996246715394312e-07,
#   'epoch': 0.03699279411198027,
#   'percentage': 1.23,
#   'elapsed_time': '0:31:41',
#   'remaining_time': '1 day, 18:17:43'},
#  {'current_steps': 120,
#   'total_steps': 9729,
#   'eval_loss': 1.3243409395217896,
#   'epoch': 0.03699279411198027,
#   'percentage': 1.23,
#   'elapsed_time': '0:31:51',
#   'remaining_time': '1 day, 18:31:40'},
#  {'current_steps': 121,
#   'total_steps': 9729,
#   'eval_loss': 1.3251513242721558,
#   'epoch': 0.03730106739624677,
#   'percentage': 1.24,
#   'elapsed_time': '0:32:07',
#   'remaining_time': '1 day, 18:31:16'},
#  {'current_steps': 122,
#   'total_steps': 9729,
#   'eval_loss': 1.323337435722351,
#   'epoch': 0.037609340680513276,
#   'percentage': 1.25,
#   'elapsed_time': '0:32:24',
#   'remaining_time': '1 day, 18:32:02'},
#  {'current_steps': 123,
#   'total_steps': 9729,
#   'eval_loss': 1.322250485420227,
#   'epoch': 0.03791761396477978,
#   'percentage': 1.26,
#   'elapsed_time': '0:32:39',
#   'remaining_time': '1 day, 18:30:56'},
#  {'current_steps': 124,
#   'total_steps': 9729,
#   'eval_loss': 1.3200721740722656,
#   'epoch': 0.03822588724904628,
#   'percentage': 1.27,
#   'elapsed_time': '0:32:56',
#   'remaining_time': '1 day, 18:31:02'},
#  {'current_steps': 125,
#   'total_steps': 9729,
#   'eval_loss': 1.3194791078567505,
#   'epoch': 0.03853416053331278,
#   'percentage': 1.28,
#   'elapsed_time': '0:33:11',
#   'remaining_time': '1 day, 18:30:16'},
#  {'current_steps': 126,
#   'total_steps': 9729,
#   'eval_loss': 1.3189159631729126,
#   'epoch': 0.038842433817579285,
#   'percentage': 1.3,
#   'elapsed_time': '0:33:27',
#   'remaining_time': '1 day, 18:30:16'},
#  {'current_steps': 127,
#   'total_steps': 9729,
#   'eval_loss': 1.3168977499008179,
#   'epoch': 0.03915070710184579,
#   'percentage': 1.31,
#   'elapsed_time': '0:33:42',
#   'remaining_time': '1 day, 18:28:39'},
#  {'current_steps': 128,
#   'total_steps': 9729,
#   'eval_loss': 1.3156630992889404,
#   'epoch': 0.039458980386112286,
#   'percentage': 1.32,
#   'elapsed_time': '0:33:57',
#   'remaining_time': '1 day, 18:27:05'},
#  {'current_steps': 129,
#   'total_steps': 9729,
#   'eval_loss': 1.3147435188293457,
#   'epoch': 0.03976725367037879,
#   'percentage': 1.33,
#   'elapsed_time': '0:34:14',
#   'remaining_time': '1 day, 18:27:38'},
#  {'current_steps': 130,
#   'total_steps': 9729,
#   'loss': 1.3994,
#   'learning_rate': 9.99559519917324e-07,
#   'epoch': 0.040075526954645294,
#   'percentage': 1.34,
#   'elapsed_time': '0:34:19',
#   'remaining_time': '1 day, 18:14:47'},
#  {'current_steps': 130,
#   'total_steps': 9729,
#   'eval_loss': 1.3136780261993408,
#   'epoch': 0.040075526954645294,
#   'percentage': 1.34,
#   'elapsed_time': '0:34:30',
#   'remaining_time': '1 day, 18:27:40'},
#  {'current_steps': 131,
#   'total_steps': 9729,
#   'eval_loss': 1.3140562772750854,
#   'epoch': 0.0403838002389118,
#   'percentage': 1.35,
#   'elapsed_time': '0:34:45',
#   'remaining_time': '1 day, 18:26:52'},
#  {'current_steps': 132,
#   'total_steps': 9729,
#   'eval_loss': 1.31418776512146,
#   'epoch': 0.040692073523178295,
#   'percentage': 1.36,
#   'elapsed_time': '0:35:02',
#   'remaining_time': '1 day, 18:27:38'},
#  {'current_steps': 133,
#   'total_steps': 9729,
#   'eval_loss': 1.311900019645691,
#   'epoch': 0.0410003468074448,
#   'percentage': 1.37,
#   'elapsed_time': '0:35:18',
#   'remaining_time': '1 day, 18:27:39'},
#  {'current_steps': 134,
#   'total_steps': 9729,
#   'eval_loss': 1.3099573850631714,
#   'epoch': 0.0413086200917113,
#   'percentage': 1.38,
#   'elapsed_time': '0:35:35',
#   'remaining_time': '1 day, 18:28:08'},
#  {'current_steps': 135,
#   'total_steps': 9729,
#   'eval_loss': 1.3089723587036133,
#   'epoch': 0.041616893375977806,
#   'percentage': 1.39,
#   'elapsed_time': '0:35:50',
#   'remaining_time': '1 day, 18:27:20'},
#  {'current_steps': 136,
#   'total_steps': 9729,
#   'eval_loss': 1.309117317199707,
#   'epoch': 0.041925166660244303,
#   'percentage': 1.4,
#   'elapsed_time': '0:36:06',
#   'remaining_time': '1 day, 18:27:21'},
#  {'current_steps': 137,
#   'total_steps': 9729,
#   'eval_loss': 1.3077154159545898,
#   'epoch': 0.04223343994451081,
#   'percentage': 1.41,
#   'elapsed_time': '0:36:22',
#   'remaining_time': '1 day, 18:27:08'},
#  {'current_steps': 138,
#   'total_steps': 9729,
#   'eval_loss': 1.3051031827926636,
#   'epoch': 0.04254171322877731,
#   'percentage': 1.42,
#   'elapsed_time': '0:36:38',
#   'remaining_time': '1 day, 18:26:57'},
#  {'current_steps': 139,
#   'total_steps': 9729,
#   'eval_loss': 1.3033372163772583,
#   'epoch': 0.042849986513043815,
#   'percentage': 1.43,
#   'elapsed_time': '0:36:54',
#   'remaining_time': '1 day, 18:26:46'},
#  {'current_steps': 140,
#   'total_steps': 9729,
#   'loss': 1.3445,
#   'learning_rate': 9.994891593450716e-07,
#   'epoch': 0.04315825979731031,
#   'percentage': 1.44,
#   'elapsed_time': '0:36:59',
#   'remaining_time': '1 day, 18:13:45'},
#  {'current_steps': 140,
#   'total_steps': 9729,
#   'eval_loss': 1.3034090995788574,
#   'epoch': 0.04315825979731031,
#   'percentage': 1.44,
#   'elapsed_time': '0:37:10',
#   'remaining_time': '1 day, 18:25:41'},
#  {'current_steps': 141,
#   'total_steps': 9729,
#   'eval_loss': 1.3027149438858032,
#   'epoch': 0.043466533081576816,
#   'percentage': 1.45,
#   'elapsed_time': '0:37:25',
#   'remaining_time': '1 day, 18:25:19'},
#  {'current_steps': 142,
#   'total_steps': 9729,
#   'eval_loss': 1.3037652969360352,
#   'epoch': 0.04377480636584332,
#   'percentage': 1.46,
#   'elapsed_time': '0:37:41',
#   'remaining_time': '1 day, 18:24:56'},
#  {'current_steps': 143,
#   'total_steps': 9729,
#   'eval_loss': 1.305085301399231,
#   'epoch': 0.044083079650109824,
#   'percentage': 1.47,
#   'elapsed_time': '0:37:57',
#   'remaining_time': '1 day, 18:24:19'},
#  {'current_steps': 144,
#   'total_steps': 9729,
#   'eval_loss': 1.305176854133606,
#   'epoch': 0.04439135293437632,
#   'percentage': 1.48,
#   'elapsed_time': '0:38:12',
#   'remaining_time': '1 day, 18:23:44'},
#  {'current_steps': 145,
#   'total_steps': 9729,
#   'eval_loss': 1.3067834377288818,
#   'epoch': 0.044699626218642825,
#   'percentage': 1.49,
#   'elapsed_time': '0:38:29',
#   'remaining_time': '1 day, 18:23:38'},
#  {'current_steps': 146,
#   'total_steps': 9729,
#   'eval_loss': 1.30547297000885,
#   'epoch': 0.04500789950290933,
#   'percentage': 1.5,
#   'elapsed_time': '0:38:44',
#   'remaining_time': '1 day, 18:22:54'},
#  {'current_steps': 147,
#   'total_steps': 9729,
#   'eval_loss': 1.3058778047561646,
#   'epoch': 0.04531617278717583,
#   'percentage': 1.51,
#   'elapsed_time': '0:38:59',
#   'remaining_time': '1 day, 18:21:43'},
#  {'current_steps': 148,
#   'total_steps': 9729,
#   'eval_loss': 1.3040175437927246,
#   'epoch': 0.04562444607144233,
#   'percentage': 1.52,
#   'elapsed_time': '0:39:15',
#   'remaining_time': '1 day, 18:21:53'},
#  {'current_steps': 149,
#   'total_steps': 9729,
#   'eval_loss': 1.3030140399932861,
#   'epoch': 0.045932719355708834,
#   'percentage': 1.53,
#   'elapsed_time': '0:39:31',
#   'remaining_time': '1 day, 18:21:07'},
#  {'current_steps': 150,
#   'total_steps': 9729,
#   'loss': 1.3949,
#   'learning_rate': 9.9941359055633e-07,
#   'epoch': 0.04624099263997534,
#   'percentage': 1.54,
#   'elapsed_time': '0:39:36',
#   'remaining_time': '1 day, 18:09:12'},
#  {'current_steps': 150,
#   'total_steps': 9729,
#   'eval_loss': 1.3010647296905518,
#   'epoch': 0.04624099263997534,
#   'percentage': 1.54,
#   'elapsed_time': '0:39:46',
#   'remaining_time': '1 day, 18:20:20'},
#  {'current_steps': 151,
#   'total_steps': 9729,
#   'eval_loss': 1.299774169921875,
#   'epoch': 0.04654926592424184,
#   'percentage': 1.55,
#   'elapsed_time': '0:40:02',
#   'remaining_time': '1 day, 18:19:56'},
#  {'current_steps': 152,
#   'total_steps': 9729,
#   'eval_loss': 1.298877239227295,
#   'epoch': 0.04685753920850834,
#   'percentage': 1.56,
#   'elapsed_time': '0:40:17',
#   'remaining_time': '1 day, 18:18:27'},
#  {'current_steps': 153,
#   'total_steps': 9729,
#   'eval_loss': 1.2989517450332642,
#   'epoch': 0.04716581249277484,
#   'percentage': 1.57,
#   'elapsed_time': '0:40:33',
#   'remaining_time': '1 day, 18:18:25'},
#  {'current_steps': 154,
#   'total_steps': 9729,
#   'eval_loss': 1.2983272075653076,
#   'epoch': 0.04747408577704135,
#   'percentage': 1.58,
#   'elapsed_time': '0:40:48',
#   'remaining_time': '1 day, 18:17:24'},
#  {'current_steps': 155,
#   'total_steps': 9729,
#   'eval_loss': 1.2987176179885864,
#   'epoch': 0.04778235906130785,
#   'percentage': 1.59,
#   'elapsed_time': '0:41:04',
#   'remaining_time': '1 day, 18:17:09'},
#  {'current_steps': 156,
#   'total_steps': 9729,
#   'eval_loss': 1.298425555229187,
#   'epoch': 0.048090632345574355,
#   'percentage': 1.6,
#   'elapsed_time': '0:41:20',
#   'remaining_time': '1 day, 18:16:50'},
#  {'current_steps': 157,
#   'total_steps': 9729,
#   'eval_loss': 1.2993632555007935,
#   'epoch': 0.04839890562984085,
#   'percentage': 1.61,
#   'elapsed_time': '0:41:35',
#   'remaining_time': '1 day, 18:16:05'},
#  {'current_steps': 158,
#   'total_steps': 9729,
#   'eval_loss': 1.2986706495285034,
#   'epoch': 0.048707178914107356,
#   'percentage': 1.62,
#   'elapsed_time': '0:41:51',
#   'remaining_time': '1 day, 18:15:30'},
#  {'current_steps': 159,
#   'total_steps': 9729,
#   'eval_loss': 1.299058198928833,
#   'epoch': 0.04901545219837386,
#   'percentage': 1.63,
#   'elapsed_time': '0:42:07',
#   'remaining_time': '1 day, 18:15:04'},
#  {'current_steps': 160,
#   'total_steps': 9729,
#   'loss': 1.3303,
#   'learning_rate': 9.993328143390617e-07,
#   'epoch': 0.049323725482640364,
#   'percentage': 1.64,
#   'elapsed_time': '0:42:12',
#   'remaining_time': '1 day, 18:04:24'},
#  {'current_steps': 160,
#   'total_steps': 9729,
#   'eval_loss': 1.2995167970657349,
#   'epoch': 0.049323725482640364,
#   'percentage': 1.64,
#   'elapsed_time': '0:42:23',
#   'remaining_time': '1 day, 18:14:50'},
#  {'current_steps': 161,
#   'total_steps': 9729,
#   'eval_loss': 1.2999593019485474,
#   'epoch': 0.04963199876690686,
#   'percentage': 1.65,
#   'elapsed_time': '0:42:38',
#   'remaining_time': '1 day, 18:14:16'},
#  {'current_steps': 162,
#   'total_steps': 9729,
#   'eval_loss': 1.2982280254364014,
#   'epoch': 0.049940272051173365,
#   'percentage': 1.67,
#   'elapsed_time': '0:42:55',
#   'remaining_time': '1 day, 18:14:28'},
#  {'current_steps': 163,
#   'total_steps': 9729,
#   'eval_loss': 1.2993943691253662,
#   'epoch': 0.05024854533543987,
#   'percentage': 1.68,
#   'elapsed_time': '0:43:11',
#   'remaining_time': '1 day, 18:14:41'},
#  {'current_steps': 164,
#   'total_steps': 9729,
#   'eval_loss': 1.2985122203826904,
#   'epoch': 0.05055681861970637,
#   'percentage': 1.69,
#   'elapsed_time': '0:43:27',
#   'remaining_time': '1 day, 18:14:40'},
#  {'current_steps': 165,
#   'total_steps': 9729,
#   'eval_loss': 1.2958078384399414,
#   'epoch': 0.05086509190397287,
#   'percentage': 1.7,
#   'elapsed_time': '0:43:43',
#   'remaining_time': '1 day, 18:14:12'},
#  {'current_steps': 166,
#   'total_steps': 9729,
#   'eval_loss': 1.2941982746124268,
#   'epoch': 0.051173365188239374,
#   'percentage': 1.71,
#   'elapsed_time': '0:43:59',
#   'remaining_time': '1 day, 18:13:54'},
#  {'current_steps': 167,
#   'total_steps': 9729,
#   'eval_loss': 1.2930190563201904,
#   'epoch': 0.05148163847250588,
#   'percentage': 1.72,
#   'elapsed_time': '0:44:14',
#   'remaining_time': '1 day, 18:13:19'},
#  {'current_steps': 168,
#   'total_steps': 9729,
#   'eval_loss': 1.2931524515151978,
#   'epoch': 0.05178991175677238,
#   'percentage': 1.73,
#   'elapsed_time': '0:44:31',
#   'remaining_time': '1 day, 18:13:34'},
#  {'current_steps': 169,
#   'total_steps': 9729,
#   'eval_loss': 1.2932490110397339,
#   'epoch': 0.05209818504103888,
#   'percentage': 1.74,
#   'elapsed_time': '0:44:46',
#   'remaining_time': '1 day, 18:12:35'},
#  {'current_steps': 170,
#   'total_steps': 9729,
#   'loss': 1.3319,
#   'learning_rate': 9.992468315355269e-07,
#   'epoch': 0.05240645832530538,
#   'percentage': 1.75,
#   'elapsed_time': '0:44:51',
#   'remaining_time': '1 day, 18:02:01'},
#  {'current_steps': 170,
#   'total_steps': 9729,
#   'eval_loss': 1.2946350574493408,
#   'epoch': 0.05240645832530538,
#   'percentage': 1.75,
#   'elapsed_time': '0:45:01',
#   'remaining_time': '1 day, 18:11:49'},
#  {'current_steps': 171,
#   'total_steps': 9729,
#   'eval_loss': 1.2939696311950684,
#   'epoch': 0.05271473160957189,
#   'percentage': 1.76,
#   'elapsed_time': '0:45:17',
#   'remaining_time': '1 day, 18:11:44'},
#  {'current_steps': 172,
#   'total_steps': 9729,
#   'eval_loss': 1.2947392463684082,
#   'epoch': 0.05302300489383839,
#   'percentage': 1.77,
#   'elapsed_time': '0:45:33',
#   'remaining_time': '1 day, 18:11:11'},
#  {'current_steps': 173,
#   'total_steps': 9729,
#   'eval_loss': 1.2928433418273926,
#   'epoch': 0.05333127817810489,
#   'percentage': 1.78,
#   'elapsed_time': '0:45:49',
#   'remaining_time': '1 day, 18:11:23'},
#  {'current_steps': 174,
#   'total_steps': 9729,
#   'eval_loss': 1.2919459342956543,
#   'epoch': 0.05363955146237139,
#   'percentage': 1.79,
#   'elapsed_time': '0:46:06',
#   'remaining_time': '1 day, 18:11:44'},
#  {'current_steps': 175,
#   'total_steps': 9729,
#   'eval_loss': 1.291154384613037,
#   'epoch': 0.053947824746637896,
#   'percentage': 1.8,
#   'elapsed_time': '0:46:22',
#   'remaining_time': '1 day, 18:11:30'},
#  {'current_steps': 176,
#   'total_steps': 9729,
#   'eval_loss': 1.2920151948928833,
#   'epoch': 0.0542560980309044,
#   'percentage': 1.81,
#   'elapsed_time': '0:46:37',
#   'remaining_time': '1 day, 18:10:46'},
#  {'current_steps': 177,
#   'total_steps': 9729,
#   'eval_loss': 1.2913062572479248,
#   'epoch': 0.0545643713151709,
#   'percentage': 1.82,
#   'elapsed_time': '0:46:53',
#   'remaining_time': '1 day, 18:10:54'},
#  {'current_steps': 178,
#   'total_steps': 9729,
#   'eval_loss': 1.291671633720398,
#   'epoch': 0.0548726445994374,
#   'percentage': 1.83,
#   'elapsed_time': '0:47:09',
#   'remaining_time': '1 day, 18:10:46'},
#  {'current_steps': 179,
#   'total_steps': 9729,
#   'eval_loss': 1.2911477088928223,
#   'epoch': 0.055180917883703905,
#   'percentage': 1.84,
#   'elapsed_time': '0:47:25',
#   'remaining_time': '1 day, 18:10:34'},
#  {'current_steps': 180,
#   'total_steps': 9729,
#   'loss': 1.2245,
#   'learning_rate': 9.991556430422759e-07,
#   'epoch': 0.05548919116797041,
#   'percentage': 1.85,
#   'elapsed_time': '0:47:31',
#   'remaining_time': '1 day, 18:01:34'},
#  {'current_steps': 180,
#   'total_steps': 9729,
#   'eval_loss': 1.2908815145492554,
#   'epoch': 0.05548919116797041,
#   'percentage': 1.85,
#   'elapsed_time': '0:47:42',
#   'remaining_time': '1 day, 18:10:49'},
#  {'current_steps': 181,
#   'total_steps': 9729,
#   'eval_loss': 1.29337477684021,
#   'epoch': 0.055797464452236906,
#   'percentage': 1.86,
#   'elapsed_time': '0:47:58',
#   'remaining_time': '1 day, 18:10:43'},
#  {'current_steps': 182,
#   'total_steps': 9729,
#   'eval_loss': 1.2952457666397095,
#   'epoch': 0.05610573773650341,
#   'percentage': 1.87,
#   'elapsed_time': '0:48:13',
#   'remaining_time': '1 day, 18:10:05'},
#  {'current_steps': 183,
#   'total_steps': 9729,
#   'eval_loss': 1.2969204187393188,
#   'epoch': 0.056414011020769914,
#   'percentage': 1.88,
#   'elapsed_time': '0:48:29',
#   'remaining_time': '1 day, 18:09:40'},
#  {'current_steps': 184,
#   'total_steps': 9729,
#   'eval_loss': 1.2993360757827759,
#   'epoch': 0.05672228430503642,
#   'percentage': 1.89,
#   'elapsed_time': '0:48:45',
#   'remaining_time': '1 day, 18:09:36'},
#  {'current_steps': 185,
#   'total_steps': 9729,
#   'eval_loss': 1.2983312606811523,
#   'epoch': 0.057030557589302915,
#   'percentage': 1.9,
#   'elapsed_time': '0:49:02',
#   'remaining_time': '1 day, 18:10:14'},
#  {'current_steps': 186,
#   'total_steps': 9729,
#   'eval_loss': 1.2945367097854614,
#   'epoch': 0.05733883087356942,
#   'percentage': 1.91,
#   'elapsed_time': '0:49:18',
#   'remaining_time': '1 day, 18:09:58'},
#  {'current_steps': 187,
#   'total_steps': 9729,
#   'eval_loss': 1.2930787801742554,
#   'epoch': 0.05764710415783592,
#   'percentage': 1.92,
#   'elapsed_time': '0:49:35',
#   'remaining_time': '1 day, 18:10:11'},
#  {'current_steps': 188,
#   'total_steps': 9729,
#   'eval_loss': 1.2890350818634033,
#   'epoch': 0.057955377442102426,
#   'percentage': 1.93,
#   'elapsed_time': '0:49:50',
#   'remaining_time': '1 day, 18:09:44'},
#  {'current_steps': 189,
#   'total_steps': 9729,
#   'eval_loss': 1.2872178554534912,
#   'epoch': 0.058263650726368924,
#   'percentage': 1.94,
#   'elapsed_time': '0:50:06',
#   'remaining_time': '1 day, 18:09:11'},
#  {'current_steps': 190,
#   'total_steps': 9729,
#   'loss': 1.3068,
#   'learning_rate': 9.990592498101387e-07,
#   'epoch': 0.05857192401063543,
#   'percentage': 1.95,
#   'elapsed_time': '0:50:12',
#   'remaining_time': '1 day, 18:00:26'},
#  {'current_steps': 190,
#   'total_steps': 9729,
#   'eval_loss': 1.285738468170166,
#   'epoch': 0.05857192401063543,
#   'percentage': 1.95,
#   'elapsed_time': '0:50:22',
#   'remaining_time': '1 day, 18:09:11'},
#  {'current_steps': 191,
#   'total_steps': 9729,
#   'eval_loss': 1.2850098609924316,
#   'epoch': 0.05888019729490193,
#   'percentage': 1.96,
#   'elapsed_time': '0:50:38',
#   'remaining_time': '1 day, 18:09:09'},
#  {'current_steps': 192,
#   'total_steps': 9729,
#   'eval_loss': 1.284995675086975,
#   'epoch': 0.059188470579168435,
#   'percentage': 1.97,
#   'elapsed_time': '0:50:54',
#   'remaining_time': '1 day, 18:08:41'},
#  {'current_steps': 193,
#   'total_steps': 9729,
#   'eval_loss': 1.285362958908081,
#   'epoch': 0.05949674386343493,
#   'percentage': 1.98,
#   'elapsed_time': '0:51:10',
#   'remaining_time': '1 day, 18:08:46'},
#  {'current_steps': 194,
#   'total_steps': 9729,
#   'eval_loss': 1.2860124111175537,
#   'epoch': 0.059805017147701436,
#   'percentage': 1.99,
#   'elapsed_time': '0:51:26',
#   'remaining_time': '1 day, 18:08:39'},
#  {'current_steps': 195,
#   'total_steps': 9729,
#   'eval_loss': 1.2872194051742554,
#   'epoch': 0.06011329043196794,
#   'percentage': 2.0,
#   'elapsed_time': '0:51:42',
#   'remaining_time': '1 day, 18:08:04'},
#  {'current_steps': 196,
#   'total_steps': 9729,
#   'eval_loss': 1.287326693534851,
#   'epoch': 0.060421563716234444,
#   'percentage': 2.01,
#   'elapsed_time': '0:51:58',
#   'remaining_time': '1 day, 18:07:46'},
#  {'current_steps': 197,
#   'total_steps': 9729,
#   'eval_loss': 1.2861438989639282,
#   'epoch': 0.06072983700050094,
#   'percentage': 2.02,
#   'elapsed_time': '0:52:13',
#   'remaining_time': '1 day, 18:07:20'},
#  {'current_steps': 198,
#   'total_steps': 9729,
#   'eval_loss': 1.2843995094299316,
#   'epoch': 0.061038110284767445,
#   'percentage': 2.04,
#   'elapsed_time': '0:52:30',
#   'remaining_time': '1 day, 18:07:11'},
#  {'current_steps': 199,
#   'total_steps': 9729,
#   'eval_loss': 1.2832581996917725,
#   'epoch': 0.06134638356903395,
#   'percentage': 2.05,
#   'elapsed_time': '0:52:45',
#   'remaining_time': '1 day, 18:06:45'},
#  {'current_steps': 200,
#   'total_steps': 9729,
#   'loss': 1.4235,
#   'learning_rate': 9.989576528442161e-07,
#   'epoch': 0.06165465685330045,
#   'percentage': 2.06,
#   'elapsed_time': '0:52:51',
#   'remaining_time': '1 day, 17:58:42'},
#  {'current_steps': 200,
#   'total_steps': 9729,
#   'eval_loss': 1.2831207513809204,
#   'epoch': 0.06165465685330045,
#   'percentage': 2.06,
#   'elapsed_time': '0:53:02',
#   'remaining_time': '1 day, 18:07:00'},
#  {'current_steps': 201,
#   'total_steps': 9729,
#   'eval_loss': 1.283146858215332,
#   'epoch': 0.06196293013756695,
#   'percentage': 2.07,
#   'elapsed_time': '0:53:18',
#   'remaining_time': '1 day, 18:06:36'},
#  {'current_steps': 202,
#   'total_steps': 9729,
#   'eval_loss': 1.2832658290863037,
#   'epoch': 0.062271203421833454,
#   'percentage': 2.08,
#   'elapsed_time': '0:53:34',
#   'remaining_time': '1 day, 18:06:41'},
#  {'current_steps': 203,
#   'total_steps': 9729,
#   'eval_loss': 1.2830506563186646,
#   'epoch': 0.06257947670609995,
#   'percentage': 2.09,
#   'elapsed_time': '0:53:49',
#   'remaining_time': '1 day, 18:05:57'},
#  {'current_steps': 204,
#   'total_steps': 9729,
#   'eval_loss': 1.28367280960083,
#   'epoch': 0.06288774999036646,
#   'percentage': 2.1,
#   'elapsed_time': '0:54:05',
#   'remaining_time': '1 day, 18:05:33'},
#  {'current_steps': 205,
#   'total_steps': 9729,
#   'eval_loss': 1.2835659980773926,
#   'epoch': 0.06319602327463296,
#   'percentage': 2.11,
#   'elapsed_time': '0:54:20',
#   'remaining_time': '1 day, 18:04:26'},
#  {'current_steps': 206,
#   'total_steps': 9729,
#   'eval_loss': 1.2830414772033691,
#   'epoch': 0.06350429655889947,
#   'percentage': 2.12,
#   'elapsed_time': '0:54:36',
#   'remaining_time': '1 day, 18:04:05'},
#  {'current_steps': 207,
#   'total_steps': 9729,
#   'eval_loss': 1.2833075523376465,
#   'epoch': 0.06381256984316597,
#   'percentage': 2.13,
#   'elapsed_time': '0:54:51',
#   'remaining_time': '1 day, 18:03:44'},
#  {'current_steps': 208,
#   'total_steps': 9729,
#   'eval_loss': 1.283144235610962,
#   'epoch': 0.06412084312743246,
#   'percentage': 2.14,
#   'elapsed_time': '0:55:07',
#   'remaining_time': '1 day, 18:03:36'},
#  {'current_steps': 209,
#   'total_steps': 9729,
#   'eval_loss': 1.2828972339630127,
#   'epoch': 0.06442911641169898,
#   'percentage': 2.15,
#   'elapsed_time': '0:55:23',
#   'remaining_time': '1 day, 18:02:59'},
#  {'current_steps': 210,
#   'total_steps': 9729,
#   'loss': 1.4393,
#   'learning_rate': 9.988508532038683e-07,
#   'epoch': 0.06473738969596547,
#   'percentage': 2.16,
#   'elapsed_time': '0:55:29',
#   'remaining_time': '1 day, 17:55:13'},
#  {'current_steps': 210,
#   'total_steps': 9729,
#   'eval_loss': 1.2836536169052124,
#   'epoch': 0.06473738969596547,
#   'percentage': 2.16,
#   'elapsed_time': '0:55:39',
#   'remaining_time': '1 day, 18:03:07'},
#  {'current_steps': 211,
#   'total_steps': 9729,
#   'eval_loss': 1.2850563526153564,
#   'epoch': 0.06504566298023197,
#   'percentage': 2.17,
#   'elapsed_time': '0:55:56',
# ...
#   'percentage': 4.4,
#   'elapsed_time': '1:53:26',
#   'remaining_time': '1 day, 17:05:16'},
#  {'current_steps': 429,
#   'total_steps': 9729,
#   'eval_loss': 1.2613335847854614,
#   'epoch': 0.13224923895032947,
#   'percentage': 4.41,
#   'elapsed_time': '1:53:42',
#   'remaining_time': '1 day, 17:04:50'},
#  {'current_steps': 430,
#   'total_steps': 9729,
#   'loss': 1.3181,
#   'learning_rate': 9.951878141614026e-07,
#   'epoch': 0.13255751223459597,
#   'percentage': 4.42,
#   'elapsed_time': '1:53:47',
#   'remaining_time': '1 day, 17:00:45'},
#  {'current_steps': 430,
#   'total_steps': 9729,
#   'eval_loss': 1.2599376440048218,
#   'epoch': 0.13255751223459597,
#   'percentage': 4.42,
#   'elapsed_time': '1:53:57',
#   'remaining_time': '1 day, 17:04:31'},
#  {'current_steps': 431,
#   'total_steps': 9729,
#   'eval_loss': 1.2606319189071655,
#   'epoch': 0.13286578551886247,
#   'percentage': 4.43,
#   'elapsed_time': '1:54:13',
#   'remaining_time': '1 day, 17:04:21'},
#  {'current_steps': 432,
#   'total_steps': 9729,
#   'eval_loss': 1.261500597000122,
#   'epoch': 0.13317405880312896,
#   'percentage': 4.44,
#   'elapsed_time': '1:54:30',
#   'remaining_time': '1 day, 17:04:15'},
#  {'current_steps': 433,
#   'total_steps': 9729,
#   'eval_loss': 1.2583364248275757,
#   'epoch': 0.1334823320873955,
#   'percentage': 4.45,
#   'elapsed_time': '1:54:46',
#   'remaining_time': '1 day, 17:04:01'},
#  {'current_steps': 434,
#   'total_steps': 9729,
#   'eval_loss': 1.2582131624221802,
#   'epoch': 0.13379060537166199,
#   'percentage': 4.46,
#   'elapsed_time': '1:55:02',
#   'remaining_time': '1 day, 17:03:50'},
#  {'current_steps': 435,
#   'total_steps': 9729,
#   'eval_loss': 1.2577985525131226,
#   'epoch': 0.13409887865592848,
#   'percentage': 4.47,
#   'elapsed_time': '1:55:18',
#   'remaining_time': '1 day, 17:03:32'},
#  {'current_steps': 436,
#   'total_steps': 9729,
#   'eval_loss': 1.2585361003875732,
#   'epoch': 0.13440715194019498,
#   'percentage': 4.48,
#   'elapsed_time': '1:55:33',
#   'remaining_time': '1 day, 17:03:11'},
#  {'current_steps': 437,
#   'total_steps': 9729,
#   'eval_loss': 1.2576615810394287,
#   'epoch': 0.13471542522446148,
#   'percentage': 4.49,
#   'elapsed_time': '1:55:49',
#   'remaining_time': '1 day, 17:02:51'},
#  {'current_steps': 438,
#   'total_steps': 9729,
#   'eval_loss': 1.257431983947754,
#   'epoch': 0.13502369850872797,
#   'percentage': 4.5,
#   'elapsed_time': '1:56:05',
#   'remaining_time': '1 day, 17:02:39'},
#  {'current_steps': 439,
#   'total_steps': 9729,
#   'eval_loss': 1.2562657594680786,
#   'epoch': 0.1353319717929945,
#   'percentage': 4.51,
#   'elapsed_time': '1:56:21',
#   'remaining_time': '1 day, 17:02:29'},
#  {'current_steps': 440,
#   'total_steps': 9729,
#   'loss': 1.271,
#   'learning_rate': 9.949617699879027e-07,
#   'epoch': 0.135640245077261,
#   'percentage': 4.52,
#   'elapsed_time': '1:56:27',
#   'remaining_time': '1 day, 16:58:39'},
#  {'current_steps': 440,
#   'total_steps': 9729,
#   'eval_loss': 1.255725622177124,
#   'epoch': 0.135640245077261,
#   'percentage': 4.52,
#   'elapsed_time': '1:56:38',
#   'remaining_time': '1 day, 17:02:20'},
#  {'current_steps': 441,
#   'total_steps': 9729,
#   'eval_loss': 1.2547165155410767,
#   'epoch': 0.1359485183615275,
#   'percentage': 4.53,
#   'elapsed_time': '1:56:53',
#   'remaining_time': '1 day, 17:02:00'},
#  {'current_steps': 442,
#   'total_steps': 9729,
#   'eval_loss': 1.2559095621109009,
#   'epoch': 0.136256791645794,
#   'percentage': 4.54,
#   'elapsed_time': '1:57:09',
#   'remaining_time': '1 day, 17:01:42'},
#  {'current_steps': 443,
#   'total_steps': 9729,
#   'eval_loss': 1.2567028999328613,
#   'epoch': 0.1365650649300605,
#   'percentage': 4.55,
#   'elapsed_time': '1:57:25',
#   'remaining_time': '1 day, 17:01:29'},
#  {'current_steps': 444,
#   'total_steps': 9729,
#   'eval_loss': 1.257818341255188,
#   'epoch': 0.136873338214327,
#   'percentage': 4.56,
#   'elapsed_time': '1:57:41',
#   'remaining_time': '1 day, 17:01:04'},
#  {'current_steps': 445,
#   'total_steps': 9729,
#   'eval_loss': 1.2576472759246826,
#   'epoch': 0.1371816114985935,
#   'percentage': 4.57,
#   'elapsed_time': '1:57:57',
#   'remaining_time': '1 day, 17:01:05'},
#  {'current_steps': 446,
#   'total_steps': 9729,
#   'eval_loss': 1.2576804161071777,
#   'epoch': 0.13748988478286,
#   'percentage': 4.58,
#   'elapsed_time': '1:58:13',
#   'remaining_time': '1 day, 17:00:51'},
#  {'current_steps': 447,
#   'total_steps': 9729,
#   'eval_loss': 1.2557456493377686,
#   'epoch': 0.1377981580671265,
#   'percentage': 4.59,
#   'elapsed_time': '1:58:30',
#   'remaining_time': '1 day, 17:00:47'},
#  {'current_steps': 448,
#   'total_steps': 9729,
#   'eval_loss': 1.2552894353866577,
#   'epoch': 0.138106431351393,
#   'percentage': 4.6,
#   'elapsed_time': '1:58:46',
#   'remaining_time': '1 day, 17:00:35'},
#  {'current_steps': 449,
#   'total_steps': 9729,
#   'eval_loss': 1.2551238536834717,
#   'epoch': 0.13841470463565952,
#   'percentage': 4.62,
#   'elapsed_time': '1:59:02',
#   'remaining_time': '1 day, 17:00:26'},
#  {'current_steps': 450,
#   'total_steps': 9729,
#   'loss': 1.246,
#   'learning_rate': 9.947305648053923e-07,
#   'epoch': 0.13872297791992602,
#   'percentage': 4.63,
#   'elapsed_time': '1:59:09',
#   'remaining_time': '1 day, 16:56:53'},
#  {'current_steps': 450,
#   'total_steps': 9729,
#   'eval_loss': 1.2561267614364624,
#   'epoch': 0.13872297791992602,
#   'percentage': 4.63,
#   'elapsed_time': '1:59:19',
#   'remaining_time': '1 day, 17:00:28'},
#  {'current_steps': 451,
#   'total_steps': 9729,
#   'eval_loss': 1.2556968927383423,
#   'epoch': 0.13903125120419252,
#   'percentage': 4.64,
#   'elapsed_time': '1:59:35',
#   'remaining_time': '1 day, 17:00:20'},
#  {'current_steps': 452,
#   'total_steps': 9729,
#   'eval_loss': 1.2574313879013062,
#   'epoch': 0.13933952448845902,
#   'percentage': 4.65,
#   'elapsed_time': '1:59:51',
#   'remaining_time': '1 day, 16:59:58'},
#  {'current_steps': 453,
#   'total_steps': 9729,
#   'eval_loss': 1.2589062452316284,
#   'epoch': 0.1396477977727255,
#   'percentage': 4.66,
#   'elapsed_time': '2:00:08',
#   'remaining_time': '1 day, 16:59:59'},
#  {'current_steps': 454,
#   'total_steps': 9729,
#   'eval_loss': 1.2598986625671387,
#   'epoch': 0.139956071056992,
#   'percentage': 4.67,
#   'elapsed_time': '2:00:23',
#   'remaining_time': '1 day, 16:59:35'},
#  {'current_steps': 455,
#   'total_steps': 9729,
#   'eval_loss': 1.2615885734558105,
#   'epoch': 0.14026434434125853,
#   'percentage': 4.68,
#   'elapsed_time': '2:00:38',
#   'remaining_time': '1 day, 16:59:02'},
#  {'current_steps': 456,
#   'total_steps': 9729,
#   'eval_loss': 1.2639679908752441,
#   'epoch': 0.14057261762552503,
#   'percentage': 4.69,
#   'elapsed_time': '2:00:54',
#   'remaining_time': '1 day, 16:58:47'},
#  {'current_steps': 457,
#   'total_steps': 9729,
#   'eval_loss': 1.2670354843139648,
#   'epoch': 0.14088089090979153,
#   'percentage': 4.7,
#   'elapsed_time': '2:01:10',
#   'remaining_time': '1 day, 16:58:32'},
#  {'current_steps': 458,
#   'total_steps': 9729,
#   'eval_loss': 1.267500400543213,
#   'epoch': 0.14118916419405803,
#   'percentage': 4.71,
#   'elapsed_time': '2:01:25',
#   'remaining_time': '1 day, 16:57:52'},
#  {'current_steps': 459,
#   'total_steps': 9729,
#   'eval_loss': 1.2692292928695679,
#   'epoch': 0.14149743747832452,
#   'percentage': 4.72,
#   'elapsed_time': '2:01:41',
#   'remaining_time': '1 day, 16:57:34'},
#  {'current_steps': 460,
#   'total_steps': 9729,
#   'loss': 1.2441,
#   'learning_rate': 9.94494201024668e-07,
#   'epoch': 0.14180571076259105,
#   'percentage': 4.73,
#   'elapsed_time': '2:01:47',
#   'remaining_time': '1 day, 16:54:02'},
#  {'current_steps': 460,
#   'total_steps': 9729,
#   'eval_loss': 1.2697049379348755,
#   'epoch': 0.14180571076259105,
#   'percentage': 4.73,
#   'elapsed_time': '2:01:57',
#   'remaining_time': '1 day, 16:57:33'},
#  {'current_steps': 461,
#   'total_steps': 9729,
#   'eval_loss': 1.2676992416381836,
#   'epoch': 0.14211398404685754,
#   'percentage': 4.74,
#   'elapsed_time': '2:02:13',
#   'remaining_time': '1 day, 16:57:12'},
#  {'current_steps': 462,
#   'total_steps': 9729,
#   'eval_loss': 1.265599012374878,
#   'epoch': 0.14242225733112404,
#   'percentage': 4.75,
#   'elapsed_time': '2:02:28',
#   'remaining_time': '1 day, 16:56:47'},
#  {'current_steps': 463,
#   'total_steps': 9729,
#   'eval_loss': 1.2660367488861084,
#   'epoch': 0.14273053061539054,
#   'percentage': 4.76,
#   'elapsed_time': '2:02:45',
#   'remaining_time': '1 day, 16:56:43'},
#  {'current_steps': 464,
#   'total_steps': 9729,
#   'eval_loss': 1.2655351161956787,
#   'epoch': 0.14303880389965704,
#   'percentage': 4.77,
#   'elapsed_time': '2:03:02',
#   'remaining_time': '1 day, 16:56:42'},
#  {'current_steps': 465,
#   'total_steps': 9729,
#   'eval_loss': 1.2663793563842773,
#   'epoch': 0.14334707718392356,
#   'percentage': 4.78,
#   'elapsed_time': '2:03:17',
#   'remaining_time': '1 day, 16:56:16'},
#  {'current_steps': 466,
#   'total_steps': 9729,
#   'eval_loss': 1.2636297941207886,
#   'epoch': 0.14365535046819006,
#   'percentage': 4.79,
#   'elapsed_time': '2:03:33',
#   'remaining_time': '1 day, 16:56:02'},
#  {'current_steps': 467,
#   'total_steps': 9729,
#   'eval_loss': 1.2618294954299927,
#   'epoch': 0.14396362375245655,
#   'percentage': 4.8,
#   'elapsed_time': '2:03:49',
#   'remaining_time': '1 day, 16:55:50'},
#  {'current_steps': 468,
#   'total_steps': 9729,
#   'eval_loss': 1.2614036798477173,
#   'epoch': 0.14427189703672305,
#   'percentage': 4.81,
#   'elapsed_time': '2:04:05',
#   'remaining_time': '1 day, 16:55:40'},
#  {'current_steps': 469,
#   'total_steps': 9729,
#   'eval_loss': 1.260246992111206,
#   'epoch': 0.14458017032098955,
#   'percentage': 4.82,
#   'elapsed_time': '2:04:21',
#   'remaining_time': '1 day, 16:55:13'},
#  {'current_steps': 470,
#   'total_steps': 9729,
#   'loss': 1.2891,
#   'learning_rate': 9.942526811103152e-07,
#   'epoch': 0.14488844360525607,
#   'percentage': 4.83,
#   'elapsed_time': '2:04:26',
#   'remaining_time': '1 day, 16:51:30'},
#  {'current_steps': 470,
#   'total_steps': 9729,
#   'eval_loss': 1.257981300354004,
#   'epoch': 0.14488844360525607,
#   'percentage': 4.83,
#   'elapsed_time': '2:04:37',
#   'remaining_time': '1 day, 16:54:57'},
#  {'current_steps': 471,
#   'total_steps': 9729,
#   'eval_loss': 1.2575736045837402,
#   'epoch': 0.14519671688952257,
#   'percentage': 4.84,
#   'elapsed_time': '2:04:53',
#   'remaining_time': '1 day, 16:54:47'},
#  {'current_steps': 472,
#   'total_steps': 9729,
#   'eval_loss': 1.2570899724960327,
#   'epoch': 0.14550499017378907,
#   'percentage': 4.85,
#   'elapsed_time': '2:05:09',
#   'remaining_time': '1 day, 16:54:40'},
#  {'current_steps': 473,
#   'total_steps': 9729,
#   'eval_loss': 1.2566769123077393,
#   'epoch': 0.14581326345805556,
#   'percentage': 4.86,
#   'elapsed_time': '2:05:25',
#   'remaining_time': '1 day, 16:54:20'},
#  {'current_steps': 474,
#   'total_steps': 9729,
#   'eval_loss': 1.259260654449463,
#   'epoch': 0.14612153674232206,
#   'percentage': 4.87,
#   'elapsed_time': '2:05:41',
#   'remaining_time': '1 day, 16:54:09'},
#  {'current_steps': 475,
#   'total_steps': 9729,
#   'eval_loss': 1.2599762678146362,
#   'epoch': 0.14642981002658856,
#   'percentage': 4.88,
#   'elapsed_time': '2:05:57',
#   'remaining_time': '1 day, 16:53:47'},
#  {'current_steps': 476,
#   'total_steps': 9729,
#   'eval_loss': 1.2624411582946777,
#   'epoch': 0.14673808331085508,
#   'percentage': 4.89,
#   'elapsed_time': '2:06:14',
#   'remaining_time': '1 day, 16:53:55'},
#  {'current_steps': 477,
#   'total_steps': 9729,
#   'eval_loss': 1.26151704788208,
#   'epoch': 0.14704635659512158,
#   'percentage': 4.9,
#   'elapsed_time': '2:06:29',
#   'remaining_time': '1 day, 16:53:35'},
#  {'current_steps': 478,
#   'total_steps': 9729,
#   'eval_loss': 1.263952612876892,
#   'epoch': 0.14735462987938808,
#   'percentage': 4.91,
#   'elapsed_time': '2:06:45',
#   'remaining_time': '1 day, 16:53:17'},
#  {'current_steps': 479,
#   'total_steps': 9729,
#   'eval_loss': 1.2658861875534058,
#   'epoch': 0.14766290316365457,
#   'percentage': 4.92,
#   'elapsed_time': '2:07:02',
#   'remaining_time': '1 day, 16:53:18'},
#  {'current_steps': 480,
#   'total_steps': 9729,
#   'loss': 1.2112,
#   'learning_rate': 9.940060075806826e-07,
#   'epoch': 0.14797117644792107,
#   'percentage': 4.93,
#   'elapsed_time': '2:07:08',
#   'remaining_time': '1 day, 16:49:52'},
#  {'current_steps': 480,
#   'total_steps': 9729,
#   'eval_loss': 1.2659410238265991,
#   'epoch': 0.14797117644792107,
#   'percentage': 4.93,
#   'elapsed_time': '2:07:19',
#   'remaining_time': '1 day, 16:53:14'},
#  {'current_steps': 481,
#   'total_steps': 9729,
#   'eval_loss': 1.266364574432373,
#   'epoch': 0.1482794497321876,
#   'percentage': 4.94,
#   'elapsed_time': '2:07:34',
#   'remaining_time': '1 day, 16:52:54'},
#  {'current_steps': 482,
#   'total_steps': 9729,
#   'eval_loss': 1.2641366720199585,
#   'epoch': 0.1485877230164541,
#   'percentage': 4.95,
#   'elapsed_time': '2:07:50',
#   'remaining_time': '1 day, 16:52:43'},
#  {'current_steps': 483,
#   'total_steps': 9729,
#   'eval_loss': 1.2614654302597046,
#   'epoch': 0.1488959963007206,
#   'percentage': 4.96,
#   'elapsed_time': '2:08:07',
#   'remaining_time': '1 day, 16:52:33'},
#  {'current_steps': 484,
#   'total_steps': 9729,
#   'eval_loss': 1.2586290836334229,
#   'epoch': 0.1492042695849871,
#   'percentage': 4.97,
#   'elapsed_time': '2:08:23',
#   'remaining_time': '1 day, 16:52:17'},
#  {'current_steps': 485,
#   'total_steps': 9729,
#   'eval_loss': 1.2567232847213745,
#   'epoch': 0.14951254286925358,
#   'percentage': 4.99,
#   'elapsed_time': '2:08:38',
#   'remaining_time': '1 day, 16:51:54'},
#  {'current_steps': 486,
#   'total_steps': 9729,
#   'eval_loss': 1.2572911977767944,
#   'epoch': 0.1498208161535201,
#   'percentage': 5.0,
#   'elapsed_time': '2:08:55',
#   'remaining_time': '1 day, 16:51:55'},
#  {'current_steps': 487,
#   'total_steps': 9729,
#   'eval_loss': 1.2608509063720703,
#   'epoch': 0.1501290894377866,
#   'percentage': 5.01,
#   'elapsed_time': '2:09:10',
#   'remaining_time': '1 day, 16:51:33'},
#  {'current_steps': 488,
#   'total_steps': 9729,
#   'eval_loss': 1.2618125677108765,
#   'epoch': 0.1504373627220531,
#   'percentage': 5.02,
#   'elapsed_time': '2:09:26',
#   'remaining_time': '1 day, 16:51:13'},
#  {'current_steps': 489,
#   'total_steps': 9729,
#   'eval_loss': 1.261579155921936,
#   'epoch': 0.1507456360063196,
#   'percentage': 5.03,
#   'elapsed_time': '2:09:43',
#   'remaining_time': '1 day, 16:51:13'},
#  {'current_steps': 490,
#   'total_steps': 9729,
#   'loss': 1.2639,
#   'learning_rate': 9.937541830078565e-07,
#   'epoch': 0.1510539092905861,
#   'percentage': 5.04,
#   'elapsed_time': '2:09:48',
#   'remaining_time': '1 day, 16:47:41'},
#  {'current_steps': 490,
#   'total_steps': 9729,
#   'eval_loss': 1.263066053390503,
#   'epoch': 0.1510539092905861,
#   'percentage': 5.04,
#   'elapsed_time': '2:09:59',
#   'remaining_time': '1 day, 16:51:00'},
#  {'current_steps': 491,
#   'total_steps': 9729,
#   'eval_loss': 1.2630012035369873,
#   'epoch': 0.1513621825748526,
#   'percentage': 5.05,
#   'elapsed_time': '2:10:15',
#   'remaining_time': '1 day, 16:50:45'},
#  {'current_steps': 492,
#   'total_steps': 9729,
#   'eval_loss': 1.261338233947754,
#   'epoch': 0.15167045585911912,
#   'percentage': 5.06,
#   'elapsed_time': '2:10:31',
#   'remaining_time': '1 day, 16:50:28'},
#  {'current_steps': 493,
#   'total_steps': 9729,
#   'eval_loss': 1.259527325630188,
#   'epoch': 0.15197872914338562,
#   'percentage': 5.07,
#   'elapsed_time': '2:10:47',
#   'remaining_time': '1 day, 16:50:16'},
#  {'current_steps': 494,
#   'total_steps': 9729,
#   'eval_loss': 1.2589937448501587,
#   'epoch': 0.1522870024276521,
#   'percentage': 5.08,
#   'elapsed_time': '2:11:04',
#   'remaining_time': '1 day, 16:50:12'},
#  {'current_steps': 495,
#   'total_steps': 9729,
#   'eval_loss': 1.2586101293563843,
#   'epoch': 0.1525952757119186,
#   'percentage': 5.09,
#   'elapsed_time': '2:11:20',
#   'remaining_time': '1 day, 16:50:07'},
#  {'current_steps': 496,
#   'total_steps': 9729,
#   'eval_loss': 1.257773995399475,
#   'epoch': 0.1529035489961851,
#   'percentage': 5.1,
#   'elapsed_time': '2:11:36',
#   'remaining_time': '1 day, 16:49:59'},
#  {'current_steps': 497,
#   'total_steps': 9729,
#   'eval_loss': 1.258050799369812,
#   'epoch': 0.15321182228045163,
#   'percentage': 5.11,
#   'elapsed_time': '2:11:51',
#   'remaining_time': '1 day, 16:49:25'},
#  {'current_steps': 498,
#   'total_steps': 9729,
#   'eval_loss': 1.258104681968689,
#   'epoch': 0.15352009556471813,
#   'percentage': 5.12,
#   'elapsed_time': '2:12:08',
#   'remaining_time': '1 day, 16:49:21'}]

# %%
for entry in multiturn_data:
    print('loss' in entry)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
def extract_loss_data(data):
    steps = []
    eval_steps = []
    training_loss = []
    evaluation_loss = []
    for entry in data:
        current_step = entry['current_steps']
        if 'loss' in entry:
            steps.append(current_step)
            training_loss.append(entry['loss'])
        if 'eval_loss' in entry:
            eval_steps.append(current_step)
            evaluation_loss.append(entry['eval_loss'])
    return steps, eval_steps, training_loss, evaluation_loss

# %%
multiturn_steps, multiturn_eval_steps, multiturn_training_loss, multiturn_evaluation_loss = extract_loss_data(multiturn_data)

singleturn_steps, singleturn_eval_steps, singleturn_training_loss, singleturn_evaluation_loss = extract_loss_data(singleturn_data)

# %%
plt.figure(figsize=(12, 4), dpi=600)

# Bilingual Monolingual

# Subplot for training loss
plt.subplot(1, 2, 1)
plt.plot(multiturn_steps, multiturn_training_loss, label='Multiturn Training Loss')
plt.plot(singleturn_steps, singleturn_training_loss, label='Singleturn Training Loss')
plt.xlabel('Step')
plt.ylabel('Training Loss')
# plt.title('Comparison of Training Loss: Multiturn vs Singleturn')
# plt.legend()
# plt.grid(True)

# Subplot for evaluation loss
plt.subplot(1, 2, 2)
plt.plot(multiturn_eval_steps, multiturn_evaluation_loss, label='Multiturn Evaluation Loss')
plt.plot(singleturn_eval_steps, singleturn_evaluation_loss, label='Singleturn Evaluation Loss')
plt.xlabel('Step')
plt.ylabel('Evaluation Loss')
# plt.title('Comparison of Evaluation Loss: Multiturn vs Singleturn')
# plt.legend()
# plt.grid(True)

plt.tight_layout()
plt.show()
